# %% [markdown]
# ## Installation

# %%
## Pip install method (recommended)
#pip uninstall ultralytics
#!pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# %% [markdown]
# ## Imports

# %%
#fundamental
import pandas as pd
import numpy as np

#OS and sys
import os

#yolo
from ultralytics import YOLO
import torch

# %% [markdown]
# Ultrakytics settings: `settings.yaml`
#
# `C:\Users\JFAR\AppData\Roaming\Ultralytics\settings.yaml`

# %%
# !nvidia-smi
# Out:
# Sat May 20 17:54:02 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 531.14                 Driver Version: 531.14       CUDA Version: 12.1     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                      TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf            Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Quadro P2000                  WDDM | 00000000:01:00.0  On |                  N/A |
# | N/A   57C    P8               N/A /  N/A|    613MiB /  4096MiB |      3%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      3516    C+G   ...l\Microsoft\Teams\current\Teams.exe    N/A      |
# |    0   N/A  N/A      4244    C+G   ...oogle\Chrome\Application\chrome.exe    N/A      |
# |    0   N/A  N/A      4896    C+G   ...es (x86)\Dropbox\Client\Dropbox.exe    N/A      |
# |    0   N/A  N/A      6460    C+G   ...cal\Microsoft\OneDrive\OneDrive.exe    N/A      |
# |    0   N/A  N/A      9008    C+G   ...aam7r\AcrobatNotificationClient.exe    N/A      |
# |    0   N/A  N/A      9128    C+G   ..._8wekyb3d8bbwe\Microsoft.Photos.exe    N/A      |
# |    0   N/A  N/A     11408    C+G   ...Desktop\app-3.2.3\GitHubDesktop.exe    N/A      |
# |    0   N/A  N/A     11936    C+G   C:\Windows\explorer.exe                   N/A      |
# |    0   N/A  N/A     12372    C+G   ...302.5.0_x64__8wekyb3d8bbwe\Time.exe    N/A      |
# |    0   N/A  N/A     13340    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe    N/A      |
# |    0   N/A  N/A     16252    C+G   ...am Files\CONEXANT\Flow\FlowTray.exe    N/A      |
# |    0   N/A  N/A     17564    C+G   ...siveControlPanel\SystemSettings.exe    N/A      |
# |    0   N/A  N/A     17780    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     21872    C+G   ...crosoft\Edge\Application\msedge.exe    N/A      |
# |    0   N/A  N/A     22320    C+G   ...l\Microsoft\Teams\current\Teams.exe    N/A      |
# |    0   N/A  N/A     22748    C+G   ....Search_cw5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A     23452    C+G   ...hSmith\Snagit 2019\SnagitEditor.exe    N/A      |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# ## Define directory

# %%
# Define root directory
ROOT_PATH = os.path.normpath(os.getcwd() + os.sep + os.pardir)
print(ROOT_PATH)
# Out:
# C:\Farid\gitProjects\power_line_inspection_yolov8

# %%
import torch
print(torch.cuda.is_available())

#GPU or CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# False
# cpu

# %%
print(torch.cuda.device_count())
# Out:
# 0

# %% [markdown]
# ## Train

# %%
#Data configs
data_yaml = ROOT_PATH + '\\data\\processed\\data.yaml'

#Model configs
pretrained_model = ROOT_PATH + '\\models\\runs\\detect\\best.pt'


model = YOLO(pretrained_model) 


#Modeling settings
imgsz = 768
batch_size = 128
epoch_size = 500
optimizer = 'SGD'       #optimizer to use, choices=['SGD', 'Adam', 'AdamW', 'RMSProp']
pretrained = True       #whether to use a pretrained model
lr0 = 0.0001             #initial learning rate (i.e. SGD=1E-2, Adam=1E-3)
resume = False           #resume training from last checkpoint
momentum =0.99         #SGD momentum/Adam beta1
weight_decay = 0.0001	#optimizer weight decay 5e-4

#Train
results = model.train(mode='detect',
                      data=data_yaml,
                      epochs=epoch_size,
                      imgsz=imgsz,
                      batch=batch_size,
                      optimizer = optimizer,
                      pretrained = pretrained,
                      lr0 = lr0,
                      resume = resume,
                      device = 'cpu',
                      weight_decay = weight_decay)
# Out:
# Ultralytics YOLOv8.0.105  Python-3.9.16 torch-2.0.1+cpu CPU
# yolo\engine\trainer: task=detect, mode=train, model=C:\Farid\gitProjects\power_line_inspection_yolov8\models\runs\detect\best.pt, data=C:\Farid\gitProjects\power_line_inspection_yolov8\data\processed\data.yaml, epochs=500, patience=50, batch=128, imgsz=768, save=True, save_period=-1, cache=False, device=cpu, workers=8, project=None, name=None, exist_ok=False, pretrained=True, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=0, resume=False, amp=True, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.0001, lrf=0.01, momentum=0.937, weight_decay=0.0001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=runs\detect\train
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752482  ultralytics.nn.modules.head.Detect           [6, [64, 128, 256]]
# YOLOv8n summary: 225 layers, 3012018 parameters, 3012002 gradients
#
# Transferred 355/355 items from pretrained weights
# optimizer: SGD(lr=0.0001) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0002), 63 bias
# train: Scanning C:\Farid\gitProjects\power_line_inspection_yolov8\data\processed\train\labels... 70 images, 0 backgrounds, 0 corrupt: 100%|██████████| 70/70 [00:00<00:00, 487.37it/s]
# train: New cache created: C:\Farid\gitProjects\power_line_inspection_yolov8\data\processed\train\labels.cache
# val: Scanning C:\Farid\gitProjects\power_line_inspection_yolov8\data\processed\val\labels... 15 images, 0 backgrounds, 0 corrupt: 100%|██████████| 15/15 [00:00<00:00, 537.14it/s]
# val: New cache created: C:\Farid\gitProjects\power_line_inspection_yolov8\data\processed\val\labels.cache
# Plotting labels to runs\detect\train\labels.jpg...
# Image sizes 768 train, 768 val
# Using 0 dataloader workers
# Logging results to runs\detect\train
# Starting training for 500 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/500         0G      1.515      1.376      1.792        482        768: 100%|██████████| 1/1 [00:38<00:00, 38.73s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.83s/it]
#                    all         15         58      0.789      0.509      0.608      0.275
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/500         0G      1.602      1.383      1.849        544        768: 100%|██████████| 1/1 [00:37<00:00, 37.89s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.75s/it]
#                    all         15         58      0.801      0.509      0.608      0.278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/500         0G      1.646      1.517      1.932        497        768: 100%|██████████| 1/1 [00:48<00:00, 48.18s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.82s/it]
#                    all         15         58      0.812      0.509      0.608      0.277
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/500         0G      1.647      1.489      1.917        446        768: 100%|██████████| 1/1 [00:45<00:00, 45.58s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.63s/it]
#                    all         15         58      0.804      0.509      0.609      0.275
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/500         0G      1.551      1.429      1.779        448        768: 100%|██████████| 1/1 [00:52<00:00, 52.52s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.95s/it]
#                    all         15         58      0.812      0.509      0.611      0.274
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/500         0G      1.679      1.512      1.873        538        768: 100%|██████████| 1/1 [00:44<00:00, 44.83s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.98s/it]
#                    all         15         58      0.801       0.51      0.606      0.266
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/500         0G      1.601      1.444      1.857        462        768: 100%|██████████| 1/1 [00:49<00:00, 49.84s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:02<00:00,  2.85s/it]
#                    all         15         58      0.771      0.514      0.617       0.27
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/500         0G      1.611      1.443      1.846        518        768: 100%|██████████| 1/1 [00:46<00:00, 46.68s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.49s/it]
#                    all         15         58      0.759       0.52      0.608      0.268
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/500         0G      1.622       1.45      1.844        478        768: 100%|██████████| 1/1 [00:48<00:00, 48.38s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.01s/it]
#                    all         15         58      0.761      0.517      0.607      0.269
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/500         0G       1.57      1.487      1.879        430        768: 100%|██████████| 1/1 [00:48<00:00, 48.71s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.86s/it]
#                    all         15         58      0.758      0.522      0.617      0.261
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/500         0G      1.617      1.444      1.816        570        768: 100%|██████████| 1/1 [01:00<00:00, 60.58s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.76s/it]
#                    all         15         58      0.759      0.525      0.617      0.263
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/500         0G      1.606      1.446      1.848        483        768: 100%|██████████| 1/1 [00:52<00:00, 52.14s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.58s/it]
#                    all         15         58      0.761      0.526      0.616      0.269
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/500         0G      1.691      1.537      1.899        479        768: 100%|██████████| 1/1 [00:51<00:00, 51.83s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.87s/it]
#                    all         15         58      0.752      0.529      0.616      0.262
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/500         0G      1.568      1.405      1.819        474        768: 100%|██████████| 1/1 [00:52<00:00, 52.78s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.65s/it]
#                    all         15         58      0.753      0.519      0.616      0.264
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/500         0G      1.576      1.445       1.83        520        768: 100%|██████████| 1/1 [00:51<00:00, 51.84s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3
80s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.43s/it]
#                    all         15         58      0.681      0.536      0.591      0.244
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/500         0G      1.639      1.453      1.868        543        768: 100%|██████████| 1/1 [00:51<00:00, 51.64s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.97s/it]
#                    all         15         58      0.685      0.538       0.59      0.244
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/500         0G      1.582      1.407      1.807        508        768: 100%|██████████| 1/1 [00:51<00:00, 51.31s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.35s/it]
#                    all         15         58       0.69      0.537       0.59      0.247
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/500         0G      1.629      1.535      1.926        455        768: 100%|██████████| 1/1 [00:51<00:00, 51.53s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.91s/it]
#                    all         15         58      0.693      0.539       0.59      0.249
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/500         0G      1.662      1.498      1.853        480        768: 100%|██████████| 1/1 [00:55<00:00, 55.76s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:05<00:00,  5.02s/it]
#                    all         15         58      0.694      0.543      0.591       0.25
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/500         0G       1.59      1.454      1.823        459        768: 100%|██████████| 1/1 [01:05<00:00, 65.99s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.97s/it]
#                    all         15         58      0.695      0.544      0.601      0.256
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/500         0G      1.651      1.529       1.92        530        768: 100%|██████████| 1/1 [00:54<00:00, 54.03s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.95s/it]
#                    all         15         58      0.698      0.556      0.603      0.256
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/500         0G      1.633      1.475      1.885        457        768: 100%|██████████| 1/1 [00:51<00:00, 51.36s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.46s/it]
#                    all         15         58      0.697       0.55      0.604      0.257
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/500         0G       1.65      1.489      1.836        531        768: 100%|██████████| 1/1 [00:50<00:00, 50.59s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.72s/it]
#                    all         15         58      0.695      0.548      0.604      0.257
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/500         0G      1.622      1.471      1.847        476        768: 100%|██████████| 1/1 [00:53<00:00, 53.18s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.40s/it]
#                    all         15         58      0.692      0.542      0.603      0.257
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/500         0G       1.61       1.43      1.822        464        768: 100%|██████████| 1/1 [00:50<00:00, 50.87s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.79s/it]
#                    all         15         58       0.69      0.535      0.602      0.255
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/500         0G      1.651       1.45       1.88        538        768: 100%|██████████| 1/1 [00:51<00:00, 51.86s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.62s/it]
#                    all         15         58       0.69      0.528      0.592      0.247
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/500         0G      1.594      1.427      1.825        540        768: 100%|██████████| 1/1 [00:52<00:00, 52.09s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.79s/it]
#                    all         15         58      0.683      0.526      0.591      0.247
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/500         0G      1.546      1.365      1.793        495        768: 100%|██████████| 1/1 [00:51<00:00, 51.62s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.59s/it]
#                    all         15         58      0.678      0.525      0.591      0.246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/500         0G      1.658      1.506      1.913        385        768: 100%|██████████| 1/1 [00:50<00:00, 50.86s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.66s/it]
#                    all         15         58      0.676       0.52       0.59      0.245
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/500         0G      1.604      1.543      1.907        449        768: 100%|██████████| 1/1 [00:50<00:00, 50.88s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:04<00:00,  4.01s/it]
#                    all         15         58      0.679      0.518      0.589      0.246
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/500         0G      1.652      1.441      1.832        514        768: 100%|██████████| 1/1 [00:51<00:00, 51.64s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.42s/it]
#                    all         15         58      0.683      0.518       0.59      0.244
# Stopping training early as no improvement observed in last 50 epochs. Best results observed at epoch 2, best model saved as best.pt.
# To update EarlyStopping(patience=50) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 52 epochs completed in 0.808 hours.
# Optimizer stripped from runs\detect\train\weights\last.pt, 6.2MB
# Optimizer stripped from runs\detect\train\weights\best.pt, 6.2MB
#
# Validating runs\detect\train\weights\best.pt...
# Ultralytics YOLOv8.0.105  Python-3.9.16 torch-2.0.1+cpu CPU
# YOLOv8n summary (fused): 168 layers, 3006818 parameters, 0 gradients
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:03<00:00,  3.13s/it]
#                    all         15         58        0.8      0.509      0.608      0.278
#               crossarm         15          5          1      0.258      0.401     0.0405
#                cutouts         15          4      0.757       0.75      0.856      0.518
#              insulator         15         28      0.878       0.25      0.423      0.175
#                   pole         15         16      0.686      0.688       0.66      0.329
#           transformers         15          5      0.676        0.6      0.699      0.329
# Speed: 2.2ms preprocess, 182.1ms inference, 0.0ms loss, 4.1ms postprocess per image
# Results saved to runs\detect\train

# %% [markdown]
# ## Hyperparm

# %% [markdown]
# ## Validate
