# %% [markdown]
# ## Installation

# %%
## Pip install method (recommended)
#!pip install ultralytics
#!pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# %% [markdown]
# ## Imports

# %%
#fundamental
import pandas as pd
import numpy as np


#OS and sys
import os

#yolo
from ultralytics import YOLO

# %%
# !nvidia-smi
# Out:
# Sun May 14 23:31:18 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.89       Driver Version: 460.89       CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Quadro P2000       WDDM  | 00000000:01:00.0  On |                  N/A |
# | N/A   66C    P5    N/A /  N/A |   1339MiB /  4096MiB |     18%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1440    C+G   Insufficient Permissions        N/A      |
# |    0   N/A  N/A      3288    C+G   ...t\Teams\current\Teams.exe    N/A      |
# |    0   N/A  N/A      6720    C+G   ...ONEXANT\Flow\FlowTray.exe    N/A      |
# |    0   N/A  N/A      7112    C+G   ...ropbox\Client\Dropbox.exe    N/A      |
# |    0   N/A  N/A      9272    C+G   ...me\Application\chrome.exe    N/A      |
# |    0   N/A  N/A     10644    C+G   ...5n1h2txyewy\SearchApp.exe    N/A      |
# |    0   N/A  N/A     10660    C+G   ...icrosoft VS Code\Code.exe    N/A      |
# |    0   N/A  N/A     11420    C+G   ...ons\Grammarly.Desktop.exe    N/A      |
# |    0   N/A  N/A     11864    C+G   ...y\ShellExperienceHost.exe    N/A      |
# |    0   N/A  N/A     13140    C+G   ...lPanel\SystemSettings.exe    N/A      |
# |    0   N/A  N/A     13928    C+G   C:\Windows\explorer.exe         N/A      |
# |    0   N/A  N/A     15196    C+G   ...artMenuExperienceHost.exe    N/A      |
# |    0   N/A  N/A     15208    C+G   ...batNotificationClient.exe    N/A      |
# |    0   N/A  N/A     16520    C+G   ...2txyewy\TextInputHost.exe    N/A      |
# |    0   N/A  N/A     17484    C+G   ...git 2019\SnagitEditor.exe    N/A      |
# |    0   N/A  N/A     17576    C+G   ...oft\OneDrive\OneDrive.exe    N/A      |
# |    0   N/A  N/A     18924    C+G   ...t\Teams\current\Teams.exe    N/A      |
# |    0   N/A  N/A     21008    C+G   ...4__8wekyb3d8bbwe\Time.exe    N/A      |
# |    0   N/A  N/A     24780    C+G   ...root\Office16\OUTLOOK.EXE    N/A      |
# |    0   N/A  N/A     26004    C+G   ...bbwe\Microsoft.Photos.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## Define directory

# %%
# Define root directory
root_path = os.path.normpath(os.getcwd() + os.sep + os.pardir)

print(root_path)
# Out:
# c:\Farid\gitProjects\power_line_inspection_yolov8

# %%
data_path = root_path + '\\data\\'
model_yaml = data_path + 'data.yaml'
print(model_yaml)
# Out:
# c:\Farid\gitProjects\power_line_inspection_yolov8\data\data.yaml

# %% [markdown]
# ## Train

# %%
# Train the model
# Create a new YOLO model from scratch
model = YOLO('yolov8n.yaml')

# Train the model using the 'data.yaml' dataset for 25 epochs
results = model.train(mode='detect', data=model_yaml, epochs=100, batch=8)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.C2f                   [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.SPPF                  [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1     37248  ultralytics.nn.modules.C2f                   [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.Conv                  [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    123648  ultralytics.nn.modules.C2f                   [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  22        [15, 18, 21]  1    897664  ultralytics.nn.modules.Detect                [80, [64, 128, 256]]
# YOLOv8n summary: 225 layers, 3157200 parameters, 3157184 gradients, 8.9 GFLOPs
#
# Ultralytics YOLOv8.0.20  Python-3.9.16 torch-2.0.0+cpu CPU
# yolo\engine\trainer: task=detect, mode=train, model=None, data=c:\Farid\gitProjects\power_line_inspection_yolov8\data\data.yaml, epochs=100, patience=50, batch=8, imgsz=640, save=True, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, save_dir=runs\detect\train2
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.Conv                  [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.Conv                  [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.C2f                   [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.C2f                   [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.C2f                   [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.SPPF                  [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1     37248  ultralytics.nn.modules.C2f                   [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.Conv                  [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    123648  ultralytics.nn.modules.C2f                   [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  22        [15, 18, 21]  1    752482  ultralytics.nn.modules.Detect                [6, [64, 128, 256]]
# YOLOv8n summary: 225 layers, 3012018 parameters, 3012002 gradients, 8.2 GFLOPs
#
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias
# train: Scanning C:\Farid\gitProjects\power_line_inspection_yolov8\data\train\labels... 593 images, 7 backgrounds, 0 corrupt: 100%|██████████| 600/600 [00:01<00:00, 315.80it/s]
# train: New cache created: C:\Farid\gitProjects\power_line_inspection_yolov8\data\train\labels.cache
# val: Scanning C:\Farid\gitProjects\power_line_inspection_yolov8\data\val\labels... 200 images, 1 backgrounds, 0 corrupt: 100%|██████████| 200/200 [00:00<00:00, 297.09it/s]
# val: New cache created: C:\Farid\gitProjects\power_line_inspection_yolov8\data\val\labels.cache
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs\detect\train2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100         0G      4.284      4.664      4.278         81        640: 100%|██████████| 75/75 [16:48<00:00, 13.44s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [01
25s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [01:26<00:00,  6.63s/it]
#                    all        200        871      0.709      0.503      0.559      0.286
#               crossarm        200        101      0.449      0.299      0.339      0.114
#                cutouts        200         74      0.801      0.405      0.499      0.352
#              insulator        200        429      0.916      0.396      0.525      0.275
#                   pole        200        198      0.726      0.717      0.721      0.394
#           transformers        200         69      0.655      0.696       0.71      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100         0G      1.958      1.937      2.065         66        640: 100%|██████████| 75/75 [13:00<00:00, 10.40s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [01:25<00:00,  6.57s/it]
#                    all        200        871      0.751      0.513      0.599      0.302
#               crossarm        200        101      0.478      0.417      0.422      0.135
#                cutouts        200         74      0.795      0.405      0.502      0.333
#              insulator        200        429      0.862      0.506        0.6       0.32
#                   pole        200        198      0.799      0.601      0.767      0.435
#           transformers        200         69       0.82      0.638      0.708      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100         0G       1.94      1.892      2.047         99        640: 100%|██████████| 75/75 [13:07<00:00, 10.50s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [01:26<00:00,  6.69s/it]
#                    all        200        871      0.704      0.539       0.61      0.312
#               crossarm        200        101       0.47      0.422      0.402      0.135
#                cutouts        200         74      0.764      0.446      0.533      0.357
#              insulator        200        429      0.668      0.538      0.584      0.291
#                   pole        200        198      0.803      0.718       0.82      0.471
#           transformers        200         69      0.814      0.569      0.713      0.308
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100         0G      1.927      1.874      2.013         70        640: 100%|██████████| 75/75 [12:51<00:00, 10.28s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [01:22<00:00,  6.33s/it]
#                    all        200        871      0.717      0.576      0.617      0.322
#               crossarm        200        101      0.344      0.653      0.463      0.154
#                cutouts        200         74      0.746      0.436      0.539      0.348
#              insulator        200        429      0.936      0.457      0.591      0.311
#                   pole        200        198      0.823      0.727      0.805       0.48
#           transformers        200         69      0.736      0.607      0.686      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100         0G      1.954      1.875      2.029         61        640: 100%|██████████| 75/75 [12:59<00:00, 10.40s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [01:23<00:00,  6.43s/it]
#                    all        200        871      0.787      0.532      0.627      0.318
#               crossarm        200        101      0.462      0.554      0.502      0.177
#                cutouts        200         74      0.908      0.392      0.529      0.301
#              insulator        200        429      0.824      0.491      0.561      0.303
#                   pole        200        198      0.858      0.671      0.802      0.443
#           transformers        200         69      0.884       0.55       0.74      0.365
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100         0G       1.91      1.809      1.987         83        640: 100%|██████████| 75/75 [12:58<00:00, 10.38s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [01:22<00:00,  6.38s/it]
#                    all        200        871      0.764      0.562      0.647       0.33
#               crossarm        200        101      0.653      0.505      0.563      0.206
#                cutouts        200         74      0.715      0.473      0.539      0.372
#              insulator        200        429      0.843      0.513      0.591      0.326
#                   pole        200        198      0.781      0.768       0.84      0.469
#           transformers        200         69       0.83      0.551        0.7      0.276
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100         0G      1.902       1.81      1.994         64        640: 100%|██████████| 75/75 [13:05<00:00, 10.47s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 13/13 [01:25<00:00,  6.61s/it]
#                    all        200        871      0.804      0.521      0.623      0.322
#               crossarm        200        101      0.634      0.495      0.546      0.185
#                cutouts        200         74      0.874      0.432       0.57      0.373
#              insulator        200        429      0.847      0.485      0.567      0.295
#                   pole        200        198      0.808      0.753      0.788      0.458
#           transformers        200         69      0.859      0.442      0.644      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100         0G      1.907      1.831      1.998         99        640:  23%|██▎       | 17/75 [03:46<12:51, 13.31s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 6
#       3 model = YOLO('yolov8n.yaml')
#       5 # Train the model using the 'data.yaml' dataset for 25 epochs
# ----> 6 results = model.train(mode='detect', data=model_yaml, epochs=100, batch=8)
#
# File c:\Users\JFAR\Anaconda3\envs\yolo\lib\site-packages\ultralytics\yolo\engine\model.py:207, in YOLO.train(self, **kwargs)
#     205     self.trainer.model = self.trainer.get_model(weights=self.model if self.ckpt else None, cfg=self.model.yaml)
#     206     self.model = self.trainer.model
# --> 207 self.trainer.train()
#     208 # update model and cfg after training
#     209 self.model, _ = attempt_load_one_weight(str(self.trainer.best))
#
# File c:\Users\JFAR\Anaconda3\envs\yolo\lib\site-packages\ultralytics\yolo\engine\trainer.py:183, in BaseTrainer.train(self)
#     181         ddp_cleanup(command, self)
#     182 else:
# --> 183     self._do_train(int(os.getenv("RANK", -1)), world_size)
#
# File c:\Users\JFAR\Anaconda3\envs\yolo\lib\site-packages\ultralytics\yolo\engine\trainer.py:284, in BaseTrainer._do_train(self, rank, world_size)
#     282 self.tloss = None
#     283 self.optimizer.zero_grad()
# --> 284 for i, batch in pbar:
#     285     self.run_callbacks("on_train_batch_start")
#     286     # Warmup
#
# File c:\Users\JFAR\Anaconda3\envs\yolo\lib\site-packages\tqdm\std.py:1178, in tqdm.__iter__(self)
#    1175 time = self._time
#    1177 try:
# -> 1178     for obj in iterable:
#    1179         yield obj
#    1180         # Update and possibly print the progressbar.
#    1181         # Note: does not call self.update(1) for speed optimisation.
#
# File c:\Users\JFAR\Anaconda3\envs\yolo\lib\site-packages\torch\utils\data\dataloader.py:634, in _BaseDataLoaderIter.__next__(self)
#     631 if self._sampler_iter is None:
#     632     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     633     self._reset()  # type: ignore[call-arg]
# --> 634 data = self._next_data()
#     635 self._num_yielded += 1
#     636 if self._dataset_kind == _DatasetKind.Iterable and \
#     637         self._IterableDataset_len_called is not None and \
#     638         self._num_yielded > self._IterableDataset_len_called:
#
# File c:\Users\JFAR\Anaconda3\envs\yolo\lib\site-packages\torch\utils\data\dataloader.py:678, in _SingleProcessDataLoaderIter._next_data(self)
#     676 def _next_data(self):
#     677     index = self._next_index()  # may raise StopIteration
# --> 678     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     679     if self._pin_memory:
#     680         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\JFAR\Anaconda3\envs\yolo\lib\site-packages\torch\utils\data\_utils\fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File c:\Users\JFAR\Anaconda3\envs\yolo\lib\site-packages\torch\utils\data\_utils\fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File c:\Users\JFAR\Anaconda3\envs\yolo\lib\site-packages\ultralytics\yolo\data\base.py:180, in BaseDataset.__getitem__(self, index)
#     179 def __getitem__(self, index):
# --> 180     return self.transforms(self.get_label_info(index))
#
# File c:\Users\JFAR\Anaconda3\envs\yolo\lib\site-packages\ultralytics\yolo\data\augment.py:48, in Compose.__call__(self, data)
#      46 def __call__(self, data):
#      47     for t in self.transforms:
# ---> 48         data = t(data)
#      49     return data
#
# File c:\Users\JFAR\Anaconda3\envs\yolo\lib\site-packages\ultralytics\yolo\data\augment.py:48, in Compose.__call__(self, data)
#      46 def __call__(self, data):
#      47     for t in self.transforms:
# ---> 48         data = t(data)
#      49     return data
#
# File c:\Users\JFAR\Anaconda3\envs\yolo\lib\site-packages\ultralytics\yolo\data\augment.py:84, in BaseMixTransform.__call__(self, labels)
#      81     indexes = [indexes]
#      83 # get images information will be used for Mosaic or MixUp
# ---> 84 mix_labels = [self.dataset.get_label_info(i) for i in indexes]
#      86 if self.pre_transform is not None:
#      87     for i, data in enumerate(mix_labels):
#
# File c:\Users\JFAR\Anaconda3\envs\yolo\lib\site-packages\ultralytics\yolo\data\augment.py:84, in <listcomp>(.0)
#      81     indexes = [indexes]
#      83 # get images information will be used for Mosaic or MixUp
# ---> 84 mix_labels = [self.dataset.get_label_info(i) for i in indexes]
#      86 if self.pre_transform is not None:
#      87     for i, data in enumerate(mix_labels):
#
# File c:\Users\JFAR\Anaconda3\envs\yolo\lib\site-packages\ultralytics\yolo\data\base.py:184, in BaseDataset.get_label_info(self, index)
#     182 def get_label_info(self, index):
#     183     label = self.labels[index].copy()
# --> 184     label["img"], label["ori_shape"], label["resized_shape"] = self.load_image(index)
#     185     label["ratio_pad"] = (
#     186         label["resized_shape"][0] / label["ori_shape"][0],
#     187         label["resized_shape"][1] / label["ori_shape"][1],
#     188     )  # for evaluation
#     189     if self.rect:
#
# File c:\Users\JFAR\Anaconda3\envs\yolo\lib\site-packages\ultralytics\yolo\data\base.py:122, in BaseDataset.load_image(self, i)
#     120     im = np.load(fn)
#     121 else:  # read image
# --> 122     im = cv2.imread(f)  # BGR
#     123     assert im is not None, f"Image Not Found {f}"
#     124 h0, w0 = im.shape[:2]  # orig hw
#
# KeyboardInterrupt:

# %% [markdown]
# ## Validate
