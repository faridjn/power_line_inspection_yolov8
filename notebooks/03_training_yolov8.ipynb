# %% [markdown]
# ## Installation

# %%
## Pip install method (recommended)
#pip uninstall ultralytics
#!pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# %% [markdown]
# ## Imports

# %%
#fundamental
import pandas as pd
import numpy as np

#OS and sys
import os

#yolo
from ultralytics import YOLO
import torch

# %% [markdown]
# Ultrakytics settings: `settings.yaml`
#
# `C:\Users\JFAR\AppData\Roaming\Ultralytics\settings.yaml`

# %%
# !nvidia-smi
# Out:
# Tue May 23 14:15:52 2023
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 531.14                 Driver Version: 531.14       CUDA Version: 12.1     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                      TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf            Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Quadro P2000                  WDDM | 00000000:01:00.0  On |                  N/A |
# | N/A   68C    P0               N/A /  N/A|   3410MiB /  4096MiB |      1%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# ## Define directory

# %%
# Define root directory
ROOT_PATH = os.path.normpath(os.getcwd() + os.sep + os.pardir)
print(ROOT_PATH)
# Out:
# C:\Farid\gitProjects\power_line_inspection_yolov8

# %%
import torch
print(torch.cuda.is_available())

#GPU or CPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# False
# cpu

# %%
print(torch.cuda.device_count())
# Out:
# 0

# %% [markdown]
# ## Train

# %%
#Data configs
data_yaml = ROOT_PATH + '\\data\\processed\\data.yaml'


#Modeling settings
imgsz = 768
batch_size = 128
epoch_size = 500
optimizer = 'RMSProp'   #optimizer to use, choices=['SGD', 'Adam', 'AdamW', 'RMSProp']
pretrained = True      #whether to use a pretrained model
lr0 = 0.001             #initial learning rate (i.e. SGD=1E-2, Adam=1E-3)
resume = False          #resume training from last checkpoint
momentum =0.937           #SGD momentum/Adam beta1
weight_decay = 0.0005   #optimizer weight decay 5e-4
patience = 50


#Pretrianed model configs
if pretrained:
    trained_model = ROOT_PATH + '\\notebooks\\runs\detect\\best.pt'
else:
    trained_model = 'yolov8n.yaml'

model = YOLO(trained_model) 


#Train
results = model.train(mode='detect',
                      data=data_yaml,
                      epochs=epoch_size,
                      imgsz=imgsz,
                      batch=batch_size,
                      optimizer = optimizer,
                      pretrained = pretrained,
                      lr0 = lr0,
                      resume = resume,
                      device = 'cpu',
                      weight_decay = weight_decay,
                      patience = patience)
# Out:
# New https://pypi.org/project/ultralytics/8.0.107 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.105  Python-3.9.16 torch-2.0.1+cpu CPU
# ...

# %% [markdown]
# ## Hyperparm

# %% [markdown]
# ## Validate
